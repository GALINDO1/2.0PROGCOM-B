# %%
#codificador
x=str(input("Ingrese el mensaje: "))
y=x.lower()
mensaje=y
codi=""
lista=[]
word=""
for i in mensaje:
  if i=="a":
    i="i"
  elif i=="e":
    i="o"
  elif i=="i":
    i="u"
  elif i=="o":
    i="a"
  elif i=="u":
    i="e"
  elif i=="á":
    i="í"
  elif i=="é":
    i="ó"
  elif i=="í":
    i="ú"
  elif i=="ó":
    i="á"
  elif i=="ú":
    i="é"
  elif i=="b":
    i="z"
  elif i=="c":
    i="b"
  elif i=="d":
    i="c"
  elif i=="f":
    i="d"
  elif i=="g":
    i="f"
  elif i=="h":
    i="g"
  elif i=="j":
    i="h"
  elif i=="k":
    i="j"
  elif i=="l":
    i="k"
  elif i=="m":
    i="l"
  elif i=="n":
    i="m"
  elif i=="ñ":
    i="n"
  elif i=="p":
    i="ñ"
  elif i=="q":
    i="p"
  elif i=="r":
    i="q"
  elif i=="s":
    i="r"
  elif i=="t":
    i="s"
  elif i=="v":
    i="t"
  elif i=="w":
    i="v"
  elif i=="x":
    i="w"
  elif i=="y":
    i="x"
  elif i=="z":
    i="y"
  codi+=i

codi+=" "
for i in codi:
  if i!=" ":    
    word+=i
  elif i==" ":
    lista.append(word)
    word=""

final=""
for i in lista[::-1]:
  final+=(i+" ")

print(final)
# Out:
# Ingrese el mensaje: Casa, League Of Legends, á
# í kofomcr, ad koifeo biri,

# %%
#decodificador
xb=str(input("Ingrese el mensaje: "))
yb=xb.lower()
mensajeb=yb
codib=""
listab=[]
wordb=""
for i in mensajeb:
  if i=="a":
    i="o"
  elif i=="e":
    i="u"
  elif i=="i":
    i="a"
  elif i=="o":
    i="e"
  elif i=="u":
    i="i"
  elif i=="á":
    i="ó"
  elif i=="é":
    i="ú"
  elif i=="í":
    i="á"
  elif i=="ó":
    i="é"
  elif i=="ú":
    i="í"
  elif i=="b":
    i="c"
  elif i=="c":
    i="d"
  elif i=="d":
    i="f"
  elif i=="f":
    i="g"
  elif i=="g":
    i="h"
  elif i=="h":
    i="j"
  elif i=="j":
    i="k"
  elif i=="k":
    i="l"
  elif i=="l":
    i="m"
  elif i=="m":
    i="n"
  elif i=="n":
    i="ñ"  
  elif i=="ñ":
    i="p"
  elif i=="p":
    i="q"
  elif i=="q":
    i="r"
  elif i=="r":
    i="s"
  elif i=="s":
    i="t"
  elif i=="t":
    i="v"
  elif i=="v":
    i="w"
  elif i=="w":
    i="x"
  elif i=="x":
    i="y"
  elif i=="y":
    i="z"
  elif i=="z":
    i="b"
  codib+=i

codib+=" "
for i in codib:
  if i!=" ":    
    wordb+=i
  elif i==" ":
    listab.append(wordb)
    wordb=""

finalb=""
for i in listab[::-1]:
  finalb+=(i+" ")

print(finalb)
# Out:
# Ingrese el mensaje: í kofomcr, ad koifeo biri,
#  casa, league of legends, á
